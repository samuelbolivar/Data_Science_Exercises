# %% [markdown]
# # GA Data Science 16 (DAT16) - Lab6
#
# ### Regressions
#
# by Justin Breucop, adapted from Francesco Mosconi & Craig Sakuma

# %%
#usual imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from bokeh.plotting import figure,show,output_notebook
output_notebook()

# %matplotlib inline

# Statsmodel APIs
import statsmodels.api as sm
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d8ec889b-1351-441c-98bc-4bf6919bd7ea">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Load a subset of the housing data

# %%
data = pd.read_csv('../data/housing-data.csv')

# %%
data.head()
# Out:
#    sqft  bdrms  age   price
# 0  2104      3   70  399900
# 1  1600      3   28  329900
# 2  2400      3   44  369000
# 3  1416      2   49  232000
# 4  3000      4   75  539900

# %%
data_n = pd.DataFrame()
for col in data.columns:
    data_n[col] = data[col].apply(lambda x: float(x)/(10**(len(str(data[col].max()))-1)) )
data_n.head()
# Out:
#     sqft  bdrms  age  price
# 0  2.104    3.0  7.0  3.999
# 1  1.600    3.0  2.8  3.299
# 2  2.400    3.0  4.4  3.690
# 3  1.416    2.0  4.9  2.320
# 4  3.000    4.0  7.5  5.399

# %% [markdown]
# The dataset contains 4 columns. Our objective is to build a model that is able to predict the price of a house, using the information contained in the other columns (sqft, bedrooms and age)

# %%
from pandas.tools.plotting import scatter_matrix
scat = scatter_matrix(data, figsize = (8,8))

# %% [markdown]
# Run 1. x = sqft, data is raw (so graph units are nice right)

# %% [markdown]
# Let''s start with a simple model that uses the house surface to estimate the price

# %%
x = data['sqft'].values
y = data['price'].values

# %%
results = sm.OLS(y, x).fit()
slope = results.params[0]
r2 = results.rsquared
print slope
print r2
# Out:
# 165.383217896
# 0.96344245878

# %% [markdown]
# A little math terminology refresher: slope is the steepness of the line and the r squared value is a "goodness of fit" measure. It tells how much of the variability of our y & x is explained by our model. 0 is bad, 95% is good and 100% is suspect (always be wary of perfect scores).

# %%
# Here we'll build the chart for the graph

p = figure(title='Loop')
p.circle(x,y,color="blue",size=8)

x1 = range(min(x),max(x)+1)

# For loop:
y1 = []
for val in x1:
    y1.append(slope*val)

p.line(x1,y1,color='red')

show(p)
# Out:
#     <div class="plotdiv" id="514dc3c3-2138-4905-a8cd-12c544f2edc8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("514dc3c3-2138-4905-a8cd-12c544f2edc8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '514dc3c3-2138-4905-a8cd-12c544f2edc8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5d8c7847-ce91-41aa-99a4-9d3006fd66b2":{"roots":{"references":[{"attributes":{"data_source":{"id":"99baf7d0-5653-48f0-a4ad-676694b37183","type":"ColumnDataSource"},"glyph":{"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"58cc4e55-18e2-4e89-9713-d894a3eb897b","type":"Line"},"selection_glyph":null},"id":"41b124b3-21f1-470e-a7af-a7f3d8cc50e8","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"c26a268d-91c0-4471-8ef4-6d57cc47bf0f","type":"Circle"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2104,1600,2400,1416,3000,1985,1534,1427,1380,1494,1940,2000,1890,4478,1268,2300,1320,1236,2609,3031,1767,1888,1604,1962,3890,1100,1458,2526,2200,2637,1839,1000,2040,3137,1811,1437,1239,2132,4215,2162,1664,2238,2567,1200,852,1852,1203],"y":[399900,329900,369000,232000,539900,299900,314900,198999,212000,242500,239999,347000,329999,699900,259900,449900,299900,199900,499998,599000,252900,255000,242900,259900,573900,249900,464500,469000,475000,299900,349900,169900,314900,579900,285900,249900,229900,345000,549000,287000,368500,329900,314000,299000,179900,299900,239500]}},"id":"be26c415-b81e-4705-b29a-0f194fdb3a59","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"896cde99-726e-4f95-935c-5bffb89993eb","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"951e1c1a-98ed-48bb-ad3f-b215443c1416","type":"BoxAnnotation"},{"attributes":{},"id":"5727253d-7ff3-47de-83d6-004d1006cf19","type":"BasicTicker"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"0cac2bdd-6f45-447c-aea0-b310bf8d8f68","type":"BasicTicker"}},"id":"ebaec2bd-f7a7-4dd3-9ac2-59d08d3cc5a7","type":"Grid"},{"attributes":{"callback":null},"id":"4286341a-c3fa-4535-bb28-cb1c5eb0686d","type":"DataRange1d"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{},"id":"c186f5e7-3815-4e65-aae7-ce2a590e4c86","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"58cc4e55-18e2-4e89-9713-d894a3eb897b","type":"Line"},{"attributes":{"callback":null},"id":"6096dba7-0c88-423f-af36-627123ac65c3","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"5727253d-7ff3-47de-83d6-004d1006cf19","type":"BasicTicker"}},"id":"c1576536-a14b-47e0-9738-95e7e55c4a7c","type":"Grid"},{"attributes":{"overlay":{"id":"951e1c1a-98ed-48bb-ad3f-b215443c1416","type":"BoxAnnotation"},"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b7752aa3-e35d-48e9-a458-3e77ca379900","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b908eb1-a2ca-48f0-9672-4dbd0aaeeaf3","type":"Circle"},{"attributes":{},"id":"65c3f870-a308-436e-94bd-d ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     1212.
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):           1.06e-34
# Time:                        23:22:17   Log-Likelihood:                -590.53
# No. Observations:                  47   AIC:                             1183.
# Df Residuals:                      46   BIC:                             1185.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           165.3832      4.750     34.818      0.000       155.822   174.944
# ==============================================================================
# Omnibus:                        2.482   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.289   Jarque-Bera (JB):                1.600
# Skew:                           0.183   Prob(JB):                        0.449
# Kurtosis:                       3.826   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# But we don't have a y intercept, which means the line passes through 0,0 as a requirement. This works for certain models but maybe not for others.
#
# `sm.add_constant` adds a column of ones to allow for finding an intercept to your data.

# %%
X = sm.add_constant(x, prepend=True)

# %%
results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

print intercept,slope
print r2
# Out:
# 71270.4924487 134.52528772
# 0.731003783976

# %%
p = figure(title='Price vs Sqft')
p.circle(x,y,color="blue",size=8)

x1 = range(min(x),max(x)+1)

# For loop:
y1 = []
for val in x1:
    y1.append(intercept + slope*val)
# This generates y1 again, but with one line of code instead
# List Comprehension:
y1 = [intercept + slope*val for val in x1]

p.line(x1,y1,color='red')

show(p)
# Out:
#     <div class="plotdiv" id="41b35d5e-414e-4123-973b-47440fb96c18"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("41b35d5e-414e-4123-973b-47440fb96c18");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '41b35d5e-414e-4123-973b-47440fb96c18' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"eef7229c-4358-4816-aaa6-57a63875a0f5":{"roots":{"references":[{"attributes":{"formatter":{"id":"7c79c3c4-a5cb-4691-bf04-5a0b486415f1","type":"BasicTickFormatter"},"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"}},"id":"c916ebd3-c058-43fc-b0b5-a58d8913e7ff","type":"LinearAxis"},{"attributes":{"below":[{"id":"96c00277-d6ca-41f3-9e44-e091a91e74e7","type":"LinearAxis"}],"left":[{"id":"c916ebd3-c058-43fc-b0b5-a58d8913e7ff","type":"LinearAxis"}],"renderers":[{"id":"96c00277-d6ca-41f3-9e44-e091a91e74e7","type":"LinearAxis"},{"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"id":"c916ebd3-c058-43fc-b0b5-a58d8913e7ff","type":"LinearAxis"},{"id":"435c6ed2-ee3f-4a7a-bc2f-0a78fd69c2aa","type":"Grid"},{"id":"bf36cdb2-0d07-4401-813c-f81f0bf10d37","type":"BoxAnnotation"},{"id":"98a5a516-1bb6-4ac4-8141-95a20d625ac9","type":"GlyphRenderer"},{"id":"3f8360ad-052f-45b4-8ddd-1a0b8cff1806","type":"GlyphRenderer"}],"title":"Price vs Sqft","tool_events":{"id":"3200f8ab-05a1-4766-9bbf-6d2538cec3ef","type":"ToolEvents"},"tools":[{"id":"0e4762a1-37f4-46e5-b084-e70ccd97fe74","type":"PanTool"},{"id":"a70a8cef-6f1b-46ac-844f-bf35f6851a99","type":"WheelZoomTool"},{"id":"1fcd8b58-dec0-4a9e-b6c6-1638fa476cf0","type":"BoxZoomTool"},{"id":"31e837e5-d1fd-4b94-ae59-ecd6cd213f6e","type":"PreviewSaveTool"},{"id":"3bd4552f-ba8c-42fa-8c49-03b2a46414c5","type":"ResizeTool"},{"id":"fe4fe3ed-f776-4688-b090-c6bde78e5375","type":"ResetTool"},{"id":"d2e27069-176c-4943-8d81-bdb75089694a","type":"HelpTool"}],"x_range":{"id":"c47bbc38-7df0-47c6-9ec4-af8a8395b8e8","type":"DataRange1d"},"y_range":{"id":"df89fd22-6e93-4971-9ba4-c369260a81b1","type":"DataRange1d"}},"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2104,1600,2400,1416,3000,1985,1534,1427,1380,1494,1940,2000,1890,4478,1268,2300,1320,1236,2609,3031,1767,1888,1604,1962,3890,1100,1458,2526,2200,2637,1839,1000,2040,3137,1811,1437,1239,2132,4215,2162,1664,2238,2567,1200,852,1852,1203],"y":[399900,329900,369000,232000,539900,299900,314900,198999,212000,242500,239999,347000,329999,699900,259900,449900,299900,199900,499998,599000,252900,255000,242900,259900,573900,249900,464500,469000,475000,299900,349900,169900,314900,579900,285900,249900,229900,345000,549000,287000,368500,329900,314000,299000,179900,299900,239500]}},"id":"fdf73e10-6152-4b87-9cfd-e301166cff46","type":"ColumnDataSource"},{"attributes":{},"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"}},"id":"d2e27069-176c-4943-8d81-bdb75089694a","type":"HelpTool"},{"attributes":{"data_source":{"id":"99baf7d0-5653-48f0-a4ad-676694b37183","type":"ColumnDataSource"},"glyph":{"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"58cc4e55-18e2-4e89-9713-d894a3eb897b","type":"Line"},"selection_glyph":null},"id":"41b124b3-21f1-470e-a7af-a7f3d8cc50e8","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"c26a268d-91c0-4471-8ef4-6d57cc47bf0f","type":"Circle"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"}},"id":"fe4fe3ed-f776-4688-b090-c6bde78e537 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     122.3
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):           2.03e-14
# Time:                        23:22:50   Log-Likelihood:                -586.94
# No. Observations:                  47   AIC:                             1178.
# Df Residuals:                      45   BIC:                             1182.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       7.127e+04   2.61e+04      2.725      0.009      1.86e+04  1.24e+05
# x1           134.5253     12.165     11.058      0.000       110.024   159.027
# ==============================================================================
# Omnibus:                        3.751   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                2.726
# Skew:                           0.557   Prob(JB):                        0.256
# Kurtosis:                       3.390   Cond. No.                     5.88e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### EXERCISE #1
# #### Create the linear model for data_n to predict price based on age.
# #### What are the slope, intercept and r-squared?

# %%
#data_n.head()
x_exercise1 = data_n['age'].values
y_exercise1 = data_n['price'].values

X_exercise1 = sm.add_constant(x_exercise1, prepend=True)

results_exercise1 = sm.OLS(y_exercise1, X_exercise1).fit()
intercept_exercise1, slope_exercise1 = results_exercise1.params

r2_exercise1 = results_exercise1.rsquared

print intercept_exercise1,slope_exercise1
print r2_exercise1
# Out:
# 3.28310755434 0.0283120704135
# 0.0026823102022

# %% [markdown]
# #### Plot the data along with the line for the regression model

# %%
p = figure(title='Price vs Age')
p.circle(x_exercise1,y_exercise1,color="blue",size=8)

x1_exercise1 = range(int(min(x_exercise1)),int(max(x_exercise1)+1))
y1_exercise1 = [intercept_exercise1 + slope_exercise1*val for val in x1_exercise1]

p.line(x1_exercise1,y1_exercise1,color='red')

show(p)
# Out:
#     <div class="plotdiv" id="31284dc7-c77a-41d0-bdc7-93b6c2970133"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("31284dc7-c77a-41d0-bdc7-93b6c2970133");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '31284dc7-c77a-41d0-bdc7-93b6c2970133' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"020ad8b0-33e4-4c75-93b4-805f460c3d6a":{"roots":{"references":[{"attributes":{"formatter":{"id":"021ecff3-ffa8-4003-ae6e-08b2fc82fbb8","type":"BasicTickFormatter"},"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"},"ticker":{"id":"1cfc918f-5c6a-472b-b7f5-d9a14ff97ed9","type":"BasicTicker"}},"id":"f135d169-53cb-48f1-a3cf-d3478eb96903","type":"LinearAxis"},{"attributes":{"formatter":{"id":"7c79c3c4-a5cb-4691-bf04-5a0b486415f1","type":"BasicTickFormatter"},"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"}},"id":"c916ebd3-c058-43fc-b0b5-a58d8913e7ff","type":"LinearAxis"},{"attributes":{"below":[{"id":"96c00277-d6ca-41f3-9e44-e091a91e74e7","type":"LinearAxis"}],"left":[{"id":"c916ebd3-c058-43fc-b0b5-a58d8913e7ff","type":"LinearAxis"}],"renderers":[{"id":"96c00277-d6ca-41f3-9e44-e091a91e74e7","type":"LinearAxis"},{"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"id":"c916ebd3-c058-43fc-b0b5-a58d8913e7ff","type":"LinearAxis"},{"id":"435c6ed2-ee3f-4a7a-bc2f-0a78fd69c2aa","type":"Grid"},{"id":"bf36cdb2-0d07-4401-813c-f81f0bf10d37","type":"BoxAnnotation"},{"id":"98a5a516-1bb6-4ac4-8141-95a20d625ac9","type":"GlyphRenderer"},{"id":"3f8360ad-052f-45b4-8ddd-1a0b8cff1806","type":"GlyphRenderer"}],"title":"Price vs Sqft","tool_events":{"id":"3200f8ab-05a1-4766-9bbf-6d2538cec3ef","type":"ToolEvents"},"tools":[{"id":"0e4762a1-37f4-46e5-b084-e70ccd97fe74","type":"PanTool"},{"id":"a70a8cef-6f1b-46ac-844f-bf35f6851a99","type":"WheelZoomTool"},{"id":"1fcd8b58-dec0-4a9e-b6c6-1638fa476cf0","type":"BoxZoomTool"},{"id":"31e837e5-d1fd-4b94-ae59-ecd6cd213f6e","type":"PreviewSaveTool"},{"id":"3bd4552f-ba8c-42fa-8c49-03b2a46414c5","type":"ResizeTool"},{"id":"fe4fe3ed-f776-4688-b090-c6bde78e5375","type":"ResetTool"},{"id":"d2e27069-176c-4943-8d81-bdb75089694a","type":"HelpTool"}],"x_range":{"id":"c47bbc38-7df0-47c6-9ec4-af8a8395b8e8","type":"DataRange1d"},"y_range":{"id":"df89fd22-6e93-4971-9ba4-c369260a81b1","type":"DataRange1d"}},"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{},"id":"27b3573d-a6f3-4422-9f04-a0eaf4e445f5","type":"ToolEvents"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{},"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"}},"id":"d2e27069-176c-4943-8d81-bdb75089694a","type":"HelpTool"},{"attributes":{},"id":"f13cdc0b-2139-48ee-bba6-b15a5ab3d3e7","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"99baf7d0-5653-48f0-a4ad-676694b37183","type":"ColumnDataSource"},"glyph":{"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"58cc4e55-18e2-4e89-9713-d894a3eb897b","type":"Line"},"selection_glyph":null},"id":"41b124b3-21f1-470e-a7af-a7f3d8cc50e8","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3ebf9202-30a6-412d-8b79-4aa6d646db6a","type":"ColumnDataSource"},"glyph":{"id":"787c1bce-30e4-457c-b5f9-f4e2f2862965","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"fa9389e8-2754-4bfb-96a0-662d2c727938","type":"Circle"},"selection_glyph":null},"id":"7694e7ef-571d-4587-ab78-455bc2c1432a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"c26a268d-91c0-4471-8ef4-6d57cc47bf0 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %% [markdown]
# #### Bonus challenge: Change the color and shape of the data points.

# %%
p = figure(title='Price vs Age')
p.diamond(x_exercise1,y_exercise1,color="green",size=15)

x1_exercise1 = range(int(min(x_exercise1)),int(max(x_exercise1)+1))
y1_exercise1 = [intercept_exercise1 + slope_exercise1*val for val in x1_exercise1]

p.line(x1_exercise1,y1_exercise1,color='blue')

show(p)
# Out:
#     <div class="plotdiv" id="e9b59d6a-1b4f-45ba-b66c-a4ad1a339663"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e9b59d6a-1b4f-45ba-b66c-a4ad1a339663");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e9b59d6a-1b4f-45ba-b66c-a4ad1a339663' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cc5c4af5-b19b-4ee2-be4d-9103c68db4dd":{"roots":{"references":[{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"},{"attributes":{"callback":null},"id":"a1855b36-f1f2-48e6-aa97-25b5b6dfd610","type":"DataRange1d"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"d58c54c4-6145-4847-b6e3-9f1df03e6097","type":"PanTool"},{"attributes":{"callback":null},"id":"df89fd22-6e93-4971-9ba4-c369260a81b1","type":"DataRange1d"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"5727253d-7ff3-47de-83d6-004d1006cf19","type":"BasicTicker"}},"id":"c1576536-a14b-47e0-9738-95e7e55c4a7c","type":"Grid"},{"attributes":{},"id":"65c3f870-a308-436e-94bd-d8a5a24086e4","type":"ToolEvents"},{"attributes":{},"id":"b5695d09-80a7-44c3-934e-b7b55d4b97bd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"a378ee84-4a81-4205-97ae-855cc91bc6e8","type":"HelpTool"},{"attributes":{"formatter":{"id":"b5695d09-80a7-44c3-934e-b7b55d4b97bd","type":"BasicTickFormatter"},"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"0cac2bdd-6f45-447c-aea0-b310bf8d8f68","type":"BasicTicker"}},"id":"0e7e0bac-09d7-4594-ad99-ec3ee4e28979","type":"LinearAxis"},{"attributes":{"callback":null},"id":"5c233abc-7e2f-4646-9fdb-fe005f77ac66","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"787c1bce-30e4-457c-b5f9-f4e2f2862965","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e2cf3746-8a9b-4067-bbc1-4c8539e345bd","type":"Line"},{"attributes":{},"id":"0cac2bdd-6f45-447c-aea0-b310bf8d8f68","type":"BasicTicker"},{"attributes":{"overlay":{"id":"eab11238-e660-4490-b5c2-96680697a154","type":"BoxAnnotation"},"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"462e4ea6-bf13-4831-a29c-d69288af9fd3","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"167956bb-b3d4-4ed8-bcb9-82cdc48adc70","type":"ColumnDataSource"},"glyph":{"id":"f99e5ec0-4cd1-4b3e-aae1-40a374c0873b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"e2cf3746-8a9b-4067-bbc1-4c8539e345bd","type":"Line"},"selection_glyph":null},"id":"6e392c5b-e9fc-4b58-b0ac-464d26b1a7cd","type":"GlyphRenderer"},{"attributes":{},"id":"b7c56bdd-479b-4e97-9864-e68b7bab6eb5","type":"BasicTickFormatter"},{"attributes":{},"id":"f13cdc0b-2139-48ee-bba6-b15a5ab3d3e7","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"c26a268d-91c0-4471-8ef4-6d57cc47bf0f","type":"Circle"},{"attributes":{},"id":"99cb5ce0-eb47-41fd-b4 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[16]</strong>&gt;</code></p>

# %% [markdown]
# Confidence Intervals

# %% [markdown]
# Something to entertain you, definitely not necessary but fun to know a short cut.

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std

prstd, iv_l, iv_u = wls_prediction_std(results)

# %%
p2 = figure(title="Confidence Intervals for Price to Sqft")
p2.circle(x, y,size=4)
p2.line(x, results.fittedvalues, color='red',line_width=4)
p2.line(x, iv_u, color='red',line_width=2)
p2.line(x, iv_l, color='red',line_width=2)

show(p2)
# Out:
#     <div class="plotdiv" id="779322a5-7db5-44ae-b082-853baed10bf8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("779322a5-7db5-44ae-b082-853baed10bf8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '779322a5-7db5-44ae-b082-853baed10bf8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"119688d0-28e9-409d-b6b0-174c2c9c684a":{"roots":{"references":[{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"},{"attributes":{},"id":"3571ccf2-5a6e-415d-92d2-044081e425cc","type":"BasicTicker"},{"attributes":{"data_source":{"id":"1094628f-155f-487c-bf3a-f6640ddfa476","type":"ColumnDataSource"},"glyph":{"id":"0eed2481-ffc0-462d-a089-c793a797688e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8fa6dfb4-203a-4563-a743-5d799d70cfa6","type":"Line"},"selection_glyph":null},"id":"bbb036cd-3b04-4132-9e0b-5143e834101a","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"a1855b36-f1f2-48e6-aa97-25b5b6dfd610","type":"DataRange1d"},{"attributes":{"plot":{"id":"4bc79217-cf0b-46c2-8b0e-9f5e9d409061","subtype":"Figure","type":"Plot"}},"id":"eec4b7df-840e-4e1b-bee8-3a65e0d70c82","type":"PreviewSaveTool"},{"attributes":{},"id":"effac787-21c8-42ce-b12e-429fa833bc70","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"d58c54c4-6145-4847-b6e3-9f1df03e6097","type":"PanTool"},{"attributes":{"callback":null},"id":"df89fd22-6e93-4971-9ba4-c369260a81b1","type":"DataRange1d"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2104,1600,2400,1416,3000,1985,1534,1427,1380,1494,1940,2000,1890,4478,1268,2300,1320,1236,2609,3031,1767,1888,1604,1962,3890,1100,1458,2526,2200,2637,1839,1000,2040,3137,1811,1437,1239,2132,4215,2162,1664,2238,2567,1200,852,1852,1203],"y":[399900,329900,369000,232000,539900,299900,314900,198999,212000,242500,239999,347000,329999,699900,259900,449900,299900,199900,499998,599000,252900,255000,242900,259900,573900,249900,464500,469000,475000,299900,349900,169900,314900,579900,285900,249900,229900,345000,549000,287000,368500,329900,314000,299000,179900,299900,239500]}},"id":"7d680ebc-3cf9-4791-b587-77d8883724b7","type":"ColumnDataSource"},{"attributes":{},"id":"3ac0fe96-7139-4967-9969-11af2e83608e","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"5727253d-7ff3-47de-83d6-004d1006cf19","type":"BasicTicker"}},"id":"c1576536-a14b-47e0-9738-95e7e55c4a7c","type":"Grid"},{"attributes":{},"id":"65c3f870-a308-436e-94bd-d8a5a24086e4","type":"ToolEvents"},{"attributes":{},"id":"b5695d09-80a7-44c3-934e-b7b55d4b97bd","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea00934b-12ff-4cf5-ac50-65f902d7c9cb","type":"Line"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"i ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[18]</strong>&gt;</code></p>

# %% [markdown]
# ## Function of Bedrooms?

# %% [markdown]
# Run 3:  x = bdrms, data is raw (so graph units are nice)

# %%
x = data['bdrms'].values
y = data['price'].values

X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

p = figure(title='Price vs Bedrooms')
p.circle(x,y,color="blue",size=8)

x1 = range(min(x),max(x)+1)

# For loop:
y1 = []
for val in x1:
    y1.append(intercept + slope*val)
    
# This generates y1 again, but with one line of code instead
# List Comprehension:
y1 = [intercept + slope*val for val in x1]

p.line(x1,y1,color='red')

show(p)
# Out:
#     <div class="plotdiv" id="5edd0f4a-f966-45a8-ab61-99cb5c62a65b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5edd0f4a-f966-45a8-ab61-99cb5c62a65b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5edd0f4a-f966-45a8-ab61-99cb5c62a65b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"07152a6a-3c46-4eb8-8ebf-d988e8593174":{"roots":{"references":[{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"d5d55319-ec26-43bb-95b1-be89caf3c1e5","type":"Circle"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"},{"attributes":{},"id":"3571ccf2-5a6e-415d-92d2-044081e425cc","type":"BasicTicker"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"dd2480d6-9a0e-403e-9a2f-943334080aec","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"1094628f-155f-487c-bf3a-f6640ddfa476","type":"ColumnDataSource"},"glyph":{"id":"0eed2481-ffc0-462d-a089-c793a797688e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8fa6dfb4-203a-4563-a743-5d799d70cfa6","type":"Line"},"selection_glyph":null},"id":"bbb036cd-3b04-4132-9e0b-5143e834101a","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"a1855b36-f1f2-48e6-aa97-25b5b6dfd610","type":"DataRange1d"},{"attributes":{"plot":{"id":"4bc79217-cf0b-46c2-8b0e-9f5e9d409061","subtype":"Figure","type":"Plot"}},"id":"eec4b7df-840e-4e1b-bee8-3a65e0d70c82","type":"PreviewSaveTool"},{"attributes":{},"id":"effac787-21c8-42ce-b12e-429fa833bc70","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"864f6cfd-5a5f-4ad9-adcd-b6db4c177a2c","type":"Line"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"d58c54c4-6145-4847-b6e3-9f1df03e6097","type":"PanTool"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae7c9f9f-004b-4b00-b634-4b8360cd320a","type":"Circle"},{"attributes":{"callback":null},"id":"df89fd22-6e93-4971-9ba4-c369260a81b1","type":"DataRange1d"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2104,1600,2400,1416,3000,1985,1534,1427,1380,1494,1940,2000,1890,4478,1268,2300,1320,1236,2609,3031,1767,1888,1604,1962,3890,1100,1458,2526,2200,2637,1839,1000,2040,3137,1811,1437,1239,2132,4215,2162,1664,2238,2567,1200,852,1852,1203],"y":[399900,329900,369000,232000,539900,299900,314900,198999,212000,242500,239999,347000,329999,699900,259900,449900,299900,199900,499998,599000,252900,255000,242900,259900,573900,249900,464500,469000,475000,299900,349900,169900,314900,579900,285900,249900,229900,345000,549000,287000,368500,329900,314000,299000,179900,299900,239500]}},"id":"7d680ebc-3cf9-4791-b587-77d8883724b7","type":"Colum ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[19]</strong>&gt;</code></p>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     10.94
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):            0.00185
# Time:                        23:23:47   Log-Likelihood:                -612.68
# No. Observations:                  47   AIC:                             1229.
# Df Residuals:                      45   BIC:                             1233.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         1.1e+05   7.16e+04      1.537      0.131     -3.41e+04  2.54e+05
# x1          7.267e+04    2.2e+04      3.308      0.002      2.84e+04  1.17e+05
# ==============================================================================
# Omnibus:                        4.709   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.412
# Skew:                           0.691   Prob(JB):                        0.110
# Kurtosis:                       2.413   Cond. No.                         15.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = data_n['bdrms'].values
y = data_n['price'].values

X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
intercept, slope = results.params
r2 = results.rsquared

p = figure(title='Price vs bdrms')
p.circle(x,y,color="blue",size=8)

x1 = range(int(min(x)),int(max(x)+1))
# For loop:
y1 = []
for val in x1:
    y1.append(intercept + slope*val)
# This generates y1 again, but with one line of code instead
# List Comprehension:
y1 = [intercept + slope*val for val in x1]

p.line(x1,y1,color='red')
show(p)
# Out:
#     <div class="plotdiv" id="b6ad2a94-25a8-464e-b37c-6b91340f57e2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b6ad2a94-25a8-464e-b37c-6b91340f57e2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b6ad2a94-25a8-464e-b37c-6b91340f57e2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"96205849-6f27-441e-8143-892fb5cefce4":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"},"ticker":{"id":"f040c15a-e455-46d9-bc6a-69c47ab52946","type":"BasicTicker"}},"id":"dfd72852-cf53-4cc5-ba50-64792f3d888c","type":"Grid"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"},{"attributes":{},"id":"3571ccf2-5a6e-415d-92d2-044081e425cc","type":"BasicTicker"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"dd2480d6-9a0e-403e-9a2f-943334080aec","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"1094628f-155f-487c-bf3a-f6640ddfa476","type":"ColumnDataSource"},"glyph":{"id":"0eed2481-ffc0-462d-a089-c793a797688e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8fa6dfb4-203a-4563-a743-5d799d70cfa6","type":"Line"},"selection_glyph":null},"id":"bbb036cd-3b04-4132-9e0b-5143e834101a","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"a1855b36-f1f2-48e6-aa97-25b5b6dfd610","type":"DataRange1d"},{"attributes":{},"id":"73c5154b-082e-4c1e-a724-8be3a1df3a09","type":"BasicTicker"},{"attributes":{},"id":"effac787-21c8-42ce-b12e-429fa833bc70","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"8855613b-68d8-424f-bf19-fdf2bafe6d89","type":"PanTool"},{"attributes":{"overlay":{"id":"b51c453d-2459-4212-bd76-35790d34b542","type":"BoxAnnotation"},"plot":{"id":"a4b6054e-4a66-46b7-8961-754034024659","subtype":"Figure","type":"Plot"}},"id":"fa1772db-af33-4a3c-a1d3-6223529f9cb4","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"d58c54c4-6145-4847-b6e3-9f1df03e6097","type":"PanTool"},{"attributes":{"callback":null},"id":"9bac38d6-07fb-40ba-bec1-079a241a091b","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae7c9f9f-004b-4b00-b634-4b8360cd320a","type":"Circle"},{"attributes":{"callback":null},"id":"df89fd22-6e93-4971-9ba4-c369260a81b1","type":"DataRange1d"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2104,1600,2400,1416,3000,1985,1534,1427,1380,1494,1940,2000,1890,4478,1268,2300,1320,1236,2609,3031,1767,1888,1604,1962,3890,1100,1458,2526,2200,2637,1839,1000,2040,3137,1811,1437,1239,2132,4215,2 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[21]</strong>&gt;</code></p>

# %%
print results.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     10.94
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):            0.00185
# Time:                        23:23:55   Log-Likelihood:                -71.573
# No. Observations:                  47   AIC:                             147.1
# Df Residuals:                      45   BIC:                             150.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.1003      0.716      1.537      0.131        -0.341     2.542
# x1             0.7267      0.220      3.308      0.002         0.284     1.169
# ==============================================================================
# Omnibus:                        4.709   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.412
# Skew:                           0.691   Prob(JB):                        0.110
# Kurtosis:                       2.413   Cond. No.                         15.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Function of multiple variables

# %%
x = data_n[['sqft', 'bdrms','age']].values
y = data_n['price'].values

X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                     39.38
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):           2.12e-12
# Time:                        23:24:27   Log-Likelihood:                -45.641
# No. Observations:                  47   AIC:                             99.28
# Df Residuals:                      43   BIC:                             106.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.9245      0.449      2.060      0.045         0.019     1.830
# x1             1.3933      0.150      9.305      0.000         1.091     1.695
# x2            -0.0862      0.156     -0.551      0.584        -0.402     0.229
# x3            -0.0081      0.043     -0.188      0.852        -0.095     0.079
# ==============================================================================
# Omnibus:                        3.841   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                2.771
# Skew:                           0.552   Prob(JB):                        0.250
# Kurtosis:                       3.444   Cond. No.                         28.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Just sqft & bedrooms

# %%
x = data_n[['sqft', 'bdrms']].values
y = data_n['price'].values
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     60.38
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):           2.43e-13
# Time:                        23:24:34   Log-Likelihood:                -45.660
# No. Observations:                  47   AIC:                             97.32
# Df Residuals:                      44   BIC:                             102.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.8960      0.418      2.145      0.037         0.054     1.738
# x1             1.3921      0.148      9.409      0.000         1.094     1.690
# x2            -0.0874      0.155     -0.566      0.575        -0.399     0.224
# ==============================================================================
# Omnibus:                        4.083   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                2.977
# Skew:                           0.567   Prob(JB):                        0.226
# Kurtosis:                       3.484   Cond. No.                         18.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## The formula API

# %%
import statsmodels.formula.api as smf

# %%
results = smf.ols('price ~ sqft + bdrms', data=data).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     60.38
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):           2.43e-13
# Time:                        23:24:41   Log-Likelihood:                -586.77
# No. Observations:                  47   AIC:                             1180.
# Df Residuals:                      44   BIC:                             1185.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    8.96e+04   4.18e+04      2.145      0.037      5421.208  1.74e+05
# sqft         139.2107     14.795      9.409      0.000       109.393   169.028
# bdrms      -8738.0191   1.55e+04     -0.566      0.575     -3.99e+04  2.24e+04
# ==============================================================================
# Omnibus:                        4.083   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                2.977
# Skew:                           0.567   Prob(JB):                        0.226
# Kurtosis:                       3.484   Cond. No.                     9.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Nonlinear Fitting

# %% [markdown]
# Let's generate points with an arbitrary nonlinear function

# %% [markdown]
# $y = \frac{1}{2} x + \frac{1}{2} \sin{x} - \frac{1}{50} (x-5)^2 + 5$

# %% [markdown]
# Note: np.c\_ is shorthand in numpy for combining columns

# %%
# start with some fake data
nsample = 50
sig = 0.5
# generate linear space
x = np.linspace(0, 20, nsample)
# invent function
X = np.c_[x, np.sin(x), (x - 5)**2, np.ones(nsample)]
# invent coefficients
beta = [1.5, 2.5, -0.2, 15.]
# generate |
y_true = np.dot(X, beta)
# add noise
y = y_true + sig * np.random.normal(size=nsample)

# %%
X = np.c_[x, np.sin(x), (x - 5)**2, np.ones(nsample)]
X.shape
x.shape
y_true.shape
# Out:
# (50,)

# %%
np.random.normal(size=nsample)
# Out:
# array([ 0.52493497, -0.44663778, -0.71373828,  0.60514673, -0.95276336,
#         0.44811523,  1.03047102,  0.27586855, -1.54018188, -1.55261817,
#         0.33873515, -1.22120229, -2.00487825,  0.55672249, -0.31107985,
#        -0.54424959,  0.57380178, -0.75061032,  0.61234322, -0.5364982 ,
#         1.35170471,  1.37662271,  0.69358808, -0.32414576, -1.34815413,
#        -1.39664511,  0.73767847, -0.40870391, -1.03573145,  0.57654976,
#         0.11580385,  1.31668691,  0.73446639,  0.45284136,  0.4916234 ,
#         0.83461117,  0.56197763, -0.42698046,  1.43727072,  1.27513778,
#         0.65519727, -0.18937118,  0.84630364,  0.43477346, -0.48250331,
#         0.21689485, -0.11423183, -0.36136882, -0.98177312,  0.81433636])

# %% [markdown]
# quick look at the data

# %%
p = figure()
p.line(x, y_true,line_color='blue')
p.circle(x, y, color='green')
show(p)
# Out:
#     <div class="plotdiv" id="32127ce8-d5a0-4066-984d-0bd0d891915c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("32127ce8-d5a0-4066-984d-0bd0d891915c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '32127ce8-d5a0-4066-984d-0bd0d891915c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b2ae5da8-8479-4d77-957d-dad35f472181":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"},"ticker":{"id":"f040c15a-e455-46d9-bc6a-69c47ab52946","type":"BasicTicker"}},"id":"dfd72852-cf53-4cc5-ba50-64792f3d888c","type":"Grid"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9ca0017e-adee-4cf2-9c52-e2f3ff4e799b","type":"ColumnDataSource"},"glyph":{"id":"2dc25dbe-4d3c-4367-8f68-29aa50e7cf44","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"9a7e2a1a-8b98-4a0f-bd54-04decd40eb19","type":"Circle"},"selection_glyph":null},"id":"08793c20-62b0-4bc8-ba0e-32be99f54073","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"},{"attributes":{"data_source":{"id":"f8b3b2b4-8229-4e91-8764-57c9d3e591fd","type":"ColumnDataSource"},"glyph":{"id":"a67cd198-ce3c-4bb4-8bd7-434249357514","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"12b2859d-b985-42b9-a167-4019a4b36063","type":"Line"},"selection_glyph":null},"id":"6318bb61-2dde-4c56-8a50-44430d57d345","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"dd2480d6-9a0e-403e-9a2f-943334080aec","type":"WheelZoomTool"},{"attributes":{},"id":"57591395-6ae6-4e84-82ca-c12d2215b1e5","type":"BasicTicker"},{"attributes":{"callback":null},"id":"a1855b36-f1f2-48e6-aa97-25b5b6dfd610","type":"DataRange1d"},{"attributes":{},"id":"73c5154b-082e-4c1e-a724-8be3a1df3a09","type":"BasicTicker"},{"attributes":{},"id":"effac787-21c8-42ce-b12e-429fa833bc70","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"8855613b-68d8-424f-bf19-fdf2bafe6d89","type":"PanTool"},{"attributes":{"overlay":{"id":"b51c453d-2459-4212-bd76-35790d34b542","type":"BoxAnnotation"},"plot":{"id":"a4b6054e-4a66-46b7-8961-754034024659","subtype":"Figure","type":"Plot"}},"id":"fa1772db-af33-4a3c-a1d3-6223529f9cb4","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"d58c54c4-6145-4847-b6e3-9f1df03e6097","type":"PanTool"},{"attributes":{"below":[{"id":"deb7798a-4b76-459b-aca8-bf4c0120389f","type":"LinearAxis"}],"left":[{"id":"8ca118b1-a511-48c5-bf7d-a97f07621420","type":"LinearAxis"}],"renderers":[{"id":"deb7798a-4b76-459b-aca8-bf4c0120389f","type":"LinearAxis"},{"id":"91689f47-94ac-4896-bd1f-bebaf7ed1ea2","type":"Grid"},{"id":"8ca118b1-a511-48c5-bf7d-a97f07621420","type":"LinearAxis"},{"id":"fe489696-1d1b-44ee-a132-f472ce1cd679","type":"Grid"},{"id":"0700030a-26f1-46c9-81df-b07a701ede03" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[34]</strong>&gt;</code></p>

# %%
res = sm.OLS(y, X).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     3032.
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):           7.58e-53
# Time:                        23:25:04   Log-Likelihood:                -34.861
# No. Observations:                  50   AIC:                             77.72
# Df Residuals:                      46   BIC:                             85.37
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.4643      0.027     54.984      0.000         1.411     1.518
# x2             2.4902      0.105     23.787      0.000         2.279     2.701
# x3            -0.1961      0.002    -83.871      0.000        -0.201    -0.191
# const         15.1798      0.173     87.911      0.000        14.832    15.527
# ==============================================================================
# Omnibus:                        1.316   Durbin-Watson:                   2.183
# Prob(Omnibus):                  0.518   Jarque-Bera (JB):                1.191
# Skew:                           0.364   Prob(JB):                        0.551
# Kurtosis:                       2.793   Cond. No.                         221.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# I can access the results attributes

# %%
print res.params
# Out:
# [  1.46426229   2.49016976  -0.19610433  15.17977763]

# %%
print 
res.bse
# Out:
# array([ 0.02663046,  0.10468748,  0.00233817,  0.17267293])

# %%
print res.predict()
# Out:
# [ 10.27716927  12.63099127  14.75707967  16.5197224   17.83218518
#   18.6709617   19.07963562  19.16171994  19.06365007  18.95072493
#   18.97994878  19.27423591  19.90221612  20.86695905  22.10546987
#   23.49903914  24.89274643  26.1209133   27.03432382  27.52474032
#   27.54268652  27.10557634  26.29485288  25.2426075   24.10987761
#   23.06018867  22.23268745  21.71928054  21.54953444  21.68581782
#   22.02948423  22.43707946  22.74391068  22.79110495  22.45171163  21.65156
#   20.38144532  18.69864111  16.7174893   14.59061415  12.48384655
#   10.54897844   8.89882384   7.58868381   6.60726069   5.87851421
#    5.27415472   4.63472084   3.79577847   2.61493687]

# %% [markdown]
# Let's look at the fit!

# %%
p = figure(title='Blue = True; Red = OLS')
p.circle(x, y, color='blue')
p.line(x, y_true, color='blue',line_width = 3)

prstd, iv_l, iv_u = wls_prediction_std(res)

p.line(x, res.fittedvalues, line_color= 'red', line_dash='dashed',line_width = 3)
p.line(x, iv_u, line_color= 'red', line_dash='dashed')
p.line(x, iv_l, line_color= 'red', line_dash='dashed')
show(p)
# Out:
#     <div class="plotdiv" id="70c77b80-b2d0-4b05-986a-3c34df46754c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("70c77b80-b2d0-4b05-986a-3c34df46754c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '70c77b80-b2d0-4b05-986a-3c34df46754c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7b8983bb-68fb-4b96-9898-fd68c245cf44":{"roots":{"references":[{"attributes":{"plot":{"id":"a4b6054e-4a66-46b7-8961-754034024659","subtype":"Figure","type":"Plot"}},"id":"0c01c07b-8a83-4342-ab48-fb4193dd35cd","type":"HelpTool"},{"attributes":{},"id":"3872fb54-d9f3-4a90-9856-8410d65a777c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9ca0017e-adee-4cf2-9c52-e2f3ff4e799b","type":"ColumnDataSource"},"glyph":{"id":"2dc25dbe-4d3c-4367-8f68-29aa50e7cf44","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"9a7e2a1a-8b98-4a0f-bd54-04decd40eb19","type":"Circle"},"selection_glyph":null},"id":"08793c20-62b0-4bc8-ba0e-32be99f54073","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"below":[{"id":"f7f80dec-f33e-4bd6-8508-b0d8e4daa2bf","type":"LinearAxis"}],"left":[{"id":"30937b08-a756-48c6-aa30-c2bd9855aaab","type":"LinearAxis"}],"renderers":[{"id":"f7f80dec-f33e-4bd6-8508-b0d8e4daa2bf","type":"LinearAxis"},{"id":"2e3cd003-2afe-46cb-8ea6-01a86efec232","type":"Grid"},{"id":"30937b08-a756-48c6-aa30-c2bd9855aaab","type":"LinearAxis"},{"id":"775b562b-d5a2-42b8-8010-a8beb927e8c0","type":"Grid"},{"id":"fb571389-6f68-45c5-abc5-3d46df6f60e4","type":"BoxAnnotation"},{"id":"692368ca-1542-42dc-ab3a-0f973b12ddf1","type":"GlyphRenderer"},{"id":"7989801a-ed24-48cc-a0f6-b39c97982162","type":"GlyphRenderer"},{"id":"994f70ea-dc0a-4ddd-b340-f03fbf2d36bf","type":"GlyphRenderer"},{"id":"5f855433-9d95-4646-a022-6630e3dfb57c","type":"GlyphRenderer"},{"id":"4e9b2284-1951-45e2-a114-42190eafbb97","type":"GlyphRenderer"}],"title":"Blue = True; Red = OLS","tool_events":{"id":"bc13d8b9-dacf-45c3-ba01-3a6feac0d591","type":"ToolEvents"},"tools":[{"id":"a89c2fd6-a58a-4545-8c1b-9be8339cd37f","type":"PanTool"},{"id":"2fd6d1ac-4af3-4e58-83b8-59e5cb8a5646","type":"WheelZoomTool"},{"id":"e5896e27-caf8-4fc8-b6e5-b6bc8a37eb91","type":"BoxZoomTool"},{"id":"095f5b11-bd76-42b9-8faf-535fde237ecd","type":"PreviewSaveTool"},{"id":"22b340e4-64a6-4ec2-a200-7297e80099b1","type":"ResizeTool"},{"id":"dfc1e394-7e46-4c66-9404-95d45531c999","type":"ResetTool"},{"id":"ae3fe86e-cbb4-413e-a6e1-3cf869666988","type":"HelpTool"}],"x_range":{"id":"39ac0cc8-5b8e-48ae-8bb7-457988acaf13","type":"DataRange1d"},"y_range":{"id":"502bc3e0-2b7c-43d8-86f9-e83d37cdd982","type":"DataRange1d"}},"id":"fa5934ee-add7-4b14-b3a3-85ae92189e50","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"fb571389-6f68-45c5-abc5-3d46df6f60e4","type":"BoxAnnotation"},{"attributes":{},"id":"cc10ca1d-49d6-41bd-b284-dbaf69850e4b","type":"BasicTicker"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f1 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[39]</strong>&gt;</code></p>

# %% [markdown]
# ## Overfitting

# %%
x = np.array([-0.99768, -0.69574, -0.40373, -0.10236, 0.22024, 0.47742, 0.82229,1.20044])
y = np.array([2.0885, 1.1646, 0.3287, 0.46013, 0.44808, 0.10013, -0.32952, -0.32811])

p = figure()
p.circle(x, y, size=8,color='blue')
show(p)
# Out:
#     <div class="plotdiv" id="8602cbef-347d-40a9-85e2-4474b36229e1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8602cbef-347d-40a9-85e2-4474b36229e1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8602cbef-347d-40a9-85e2-4474b36229e1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"659360f6-f4ae-4df7-b781-be182cc2ec41":{"roots":{"references":[{"attributes":{"plot":{"id":"a4b6054e-4a66-46b7-8961-754034024659","subtype":"Figure","type":"Plot"}},"id":"0c01c07b-8a83-4342-ab48-fb4193dd35cd","type":"HelpTool"},{"attributes":{"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"}},"id":"794d6de7-2f5a-444f-92da-64e1ed2fec2a","type":"PreviewSaveTool"},{"attributes":{"callback":null},"id":"84eee62b-2b3c-4d3f-99e1-a4e720b0aa1b","type":"DataRange1d"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"x":{"field":"x"},"y":{"field":"y"}},"id":"9cf597d8-bc5c-4dd4-b985-6394253d4860","type":"Line"},{"attributes":{"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"}},"id":"7e1a687c-ab3e-4ae1-977e-cf9e2ee63684","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9ca0017e-adee-4cf2-9c52-e2f3ff4e799b","type":"ColumnDataSource"},"glyph":{"id":"2dc25dbe-4d3c-4367-8f68-29aa50e7cf44","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"9a7e2a1a-8b98-4a0f-bd54-04decd40eb19","type":"Circle"},"selection_glyph":null},"id":"08793c20-62b0-4bc8-ba0e-32be99f54073","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"9c86f760-72a2-4c7c-9e86-9d286f755f5a","type":"PreviewSaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"fb571389-6f68-45c5-abc5-3d46df6f60e4","type":"BoxAnnotation"},{"attributes":{},"id":"cc10ca1d-49d6-41bd-b284-dbaf69850e4b","type":"BasicTicker"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b92630ed-3590-4ad3-b663-0c066c31ea17","type":"Line"},{"attributes":{},"id":"05ac2aaf-ebba-491a-a6ce-f17cd0267c02","type":"BasicTicker"},{"attributes":{},"id":"3571ccf2-5a6e-415d-92d2-044081e425cc","type":"BasicTicker"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"dd2480d6-9a0e-403e-9a2f-943334080aec","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"1094628f-155f-487c-bf3a-f6640ddfa476","type":"ColumnDataSource"},"glyph":{"id":"0eed2481-ffc0-462d-a089-c793a797688e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8fa6dfb4-203a-4563-a743-5d799d70cfa6","type":"Line"},"selection_glyph":null},"id":"bbb036cd-3b04-4132-9e0b-5143e834101a","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"a1855b36-f1f2-48e6-aa97-25b5b6dfd610","type":"DataRange1d"},{"attributes":{"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"}},"id":"71dc1ddb-0101-4ac4-8096-0188980bc221","type":"ResetTool"},{"attributes":{},"id":"effac787-21c8-42ce-b12e-429fa833bc70","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"b51c453d-2459-4212-bd76-35790d34b542","type":"BoxAnnotation"},"plot":{"id":"a4b6054e-4a66-46b7 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[40]</strong>&gt;</code></p>

# %% [markdown]
# np.vander yields a vandermonde matrix (fancy way of doing columns of x, x^2, x^3 etc. up to the second argument)

# %%
X = np.c_[x, np.ones(len(x))]
#X = np.vander(x, 4)
# Same as np.c_[x]

# %%
X
# Out:
# array([[-0.99768,  1.     ],
#        [-0.69574,  1.     ],
#        [-0.40373,  1.     ],
#        [-0.10236,  1.     ],
#        [ 0.22024,  1.     ],
#        [ 0.47742,  1.     ],
#        [ 0.82229,  1.     ],
#        [ 1.20044,  1.     ]])

# %%
res = sm.OLS(y, X).fit()
res.summary()
# Out:
# /Users/samuelbolivar/anaconda/lib/python2.7/site-packages/scipy/stats/stats.py:1326: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     26.31
# Date:                Mon, 05 Sep 2016   Prob (F-statistic):            0.00216
# Time:                        23:25:32   Log-Likelihood:                -2.3435
# No. Observations:                   8   AIC:                             8.687
# Df Residuals:                       6   BIC:                             8.846
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -0.9590      0.187     -5.130      0.002        -1.416    -0.502
# const          0.5540      0.133      4.167      0.006         0.229     0.879
# ==============================================================================
# Omnibus:                        0.904   Durbin-Watson:                   1.342
# Prob(Omnibus):                  0.636   Jarque-Bera (JB):                0.013
# Skew:                          -0.089   Prob(JB):                        0.994
# Kurtosis:                       2.925   Cond. No.                         1.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Linear fit

# %%
p = figure(title='Blue = True; Red = OLS')
p.circle(x, y, size=8,color='blue')

xx = np.linspace(-1.25,1.25,100)
p.line(xx, res.predict(np.vander(xx,2)), color='red')
show(p)
# Out:
#     <div class="plotdiv" id="a0f3a7c5-ce11-453b-97b3-6752a2234a39"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a0f3a7c5-ce11-453b-97b3-6752a2234a39");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a0f3a7c5-ce11-453b-97b3-6752a2234a39' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"18d8878b-9717-4021-9565-d61c435e17c8":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"},"ticker":{"id":"f040c15a-e455-46d9-bc6a-69c47ab52946","type":"BasicTicker"}},"id":"dfd72852-cf53-4cc5-ba50-64792f3d888c","type":"Grid"},{"attributes":{"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"}},"id":"794d6de7-2f5a-444f-92da-64e1ed2fec2a","type":"PreviewSaveTool"},{"attributes":{},"id":"3872fb54-d9f3-4a90-9856-8410d65a777c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"plot":{"id":"472e612c-5f6a-4f00-b81e-047db6d716a8","subtype":"Figure","type":"Plot"}},"id":"2c2aea0c-257c-40ad-b310-df20cdda74e3","type":"ResetTool"},{"attributes":{"plot":{"id":"fa5934ee-add7-4b14-b3a3-85ae92189e50","subtype":"Figure","type":"Plot"}},"id":"22b340e4-64a6-4ec2-a200-7297e80099b1","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"f79de735-1942-4221-a7ee-30f854d3a5dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"0da78a06-05e7-4864-b693-cdcb4e0c5e2f","type":"BasicTicker"}},"id":"270a3efb-7662-4a1d-8d25-896f0d7d9650","type":"Grid"},{"attributes":{"data_source":{"id":"fe3518bd-127c-4918-9d3a-fd11244010cf","type":"ColumnDataSource"},"glyph":{"id":"9ec2304f-8da9-4d0e-af6d-8a777e3140eb","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"34ce6b57-bb42-4b2d-8340-dfbb1b021aa7","type":"Line"},"selection_glyph":null},"id":"55adf0f9-a0e7-4332-ad21-e12cd6acdd7b","type":"GlyphRenderer"},{"attributes":{},"id":"0da78a06-05e7-4864-b693-cdcb4e0c5e2f","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"below":[{"id":"f7f80dec-f33e-4bd6-8508-b0d8e4daa2bf","type":"LinearAxis"}],"left":[{"id":"30937b08-a756-48c6-aa30-c2bd9855aaab","type":"LinearAxis"}],"renderers":[{"id":"f7f80dec-f33e-4bd6-8508-b0d8e4daa2bf","type":"LinearAxis"},{"id":"2e3cd003-2afe-46cb-8ea6-01a86efec232","type":"Grid"},{"id":"30937b08-a756-48c6-aa30-c2bd9855aaab","type":"LinearAxis"},{"id":"775b562b-d5a2-42b8-8010-a8beb927e8c0","type":"Grid"},{"id":"fb571389-6f68-45c5-abc5-3d46df6f60e4","type":"BoxAnnotation"},{"id":"692368ca-1542-42dc-ab3a-0f973b12ddf1","type":"GlyphRenderer"},{"id":"7989801a-ed24-48cc-a0f6-b39c97982162","type":"GlyphRenderer"},{"id":"994f70ea-dc0a-4ddd-b340-f03fbf2d36bf","type":"GlyphRenderer"},{"id":"5f855433-9d95-4646-a022-6630e3dfb57c","type":"GlyphRenderer"},{"id":"4e9b2284-1951-45e2-a114-42190eafbb97","type":"GlyphRenderer"}],"title":"Blue = True; Red = OLS","tool_events":{"id":"bc13d8b9-dacf-45c3-ba01-3a6feac0d591","type":"ToolEvents"},"tools":[{"id":"a89c2fd6-a58a-4545-8c1b-9be8339cd37f","type":"PanTool"},{"id":"2fd6d1ac-4af3-4e58-83b8-59e5cb8a5646","type":"WheelZoomTool"},{"id":"e5896e27-caf8-4fc8-b6e5-b6bc8a37eb91","type":"BoxZoomTool"},{"id":"095f5b11-bd76-42b9-8faf-535fde237ecd","type":"PreviewSaveTool"},{"id":"22b340e4-64a6-4ec2-a200-7297e80099b1","type":"ResizeTool"},{"id":"dfc1e394-7e46-4c66-9404-95d45531c999","type":"ResetTool"},{"id":"ae3fe86e-cbb4-413e-a6e1-3cf869666988","type":"HelpTool"}],"x_range":{"id":"39ac0cc8-5b8e-48ae-8bb7-457988acaf13","type":"DataRange1d"},"y_range":{"id":"502bc3e0-2b7c-43d8-86f9-e83d37cdd982","type" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[44]</strong>&gt;</code></p>

# %% [markdown]
# ### Quadratic

# %%
X = np.c_[x**2, x, np.ones(len(x))]
res = sm.OLS(y, X).fit()

p = figure(title='Blue = True; Red = OLS')
p.circle(x, y, size=8,color='blue')

xx = np.linspace(-1.25,1.25,100)
p.line(xx, res.predict(np.vander(xx,3)), color='red')
show(p)
# Out:
#     <div class="plotdiv" id="7e617317-d5a7-4c6d-9fb0-70a751b9dde1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7e617317-d5a7-4c6d-9fb0-70a751b9dde1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7e617317-d5a7-4c6d-9fb0-70a751b9dde1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ff573661-915e-41de-86ca-6bb0dc93b327":{"roots":{"references":[{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"data_source":{"id":"f8b3b2b4-8229-4e91-8764-57c9d3e591fd","type":"ColumnDataSource"},"glyph":{"id":"a67cd198-ce3c-4bb4-8bd7-434249357514","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"12b2859d-b985-42b9-a167-4019a4b36063","type":"Line"},"selection_glyph":null},"id":"6318bb61-2dde-4c56-8a50-44430d57d345","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"dd2480d6-9a0e-403e-9a2f-943334080aec","type":"WheelZoomTool"},{"attributes":{},"id":"1098c190-352a-4953-8c16-772331828eb3","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"122091de-7fc5-4d13-8ed8-acc3d06fe99a","subtype":"Figure","type":"Plot"},"ticker":{"id":"1cfc918f-5c6a-472b-b7f5-d9a14ff97ed9","type":"BasicTicker"}},"id":"9ead3ada-e154-4763-8c10-dcca735d514a","type":"Grid"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"5727253d-7ff3-47de-83d6-004d1006cf19","type":"BasicTicker"}},"id":"c1576536-a14b-47e0-9738-95e7e55c4a7c","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.99768,-0.69574,-0.40373,-0.10236,0.22024,0.47742,0.82229,1.20044],"y":[2.0885,1.1646,0.3287,0.46013,0.44808,0.10013,-0.32952,-0.32811]}},"id":"5f36558a-780c-457b-8aef-db721e1de8fe","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"a20e7094-219b-49c0-a9b3-2b6460569f76","type":"DataRange1d"},{"attributes":{"plot":{"id":"472e612c-5f6a-4f00-b81e-047db6d716a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"9deb8d4a-3ccd-4366-a7de-77b23a60ebe4","type":"BasicTicker"}},"id":"f8833145-6bef-462e-8716-8a263f35cc4e","type":"Grid"},{"attributes":{"formatter":{"id":"45f78c21-448e-4a83-9243-3f7a7f8fab91","type":"BasicTickFormatter"},"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"},"ticker":{"id":"99cb5ce0-eb47-41fd-b40a-46c3dc4a918e","type":"BasicTicker"}},"id":"99ffd02f-30a3-49e1-a6a3-5ef36f7cb60f","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c4ab10e6-c6a6-4949-b80e-a8cabb4b6083","type":"Line"},{"attributes":{"data_source":{"id":"7d680ebc-3cf9-4791-b587-77d8883724b7","type":"ColumnDataSource"},"glyph":{"id":"7fd493d2-6d9f-40c1-8d9e-2970439fa619","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"73660669-242e-41f1-9c15-73320c869a87","type":"Circle"},"selection_glyph":null},"id":"cf679437-ee09-46b5-9be0-a9618db6ab0f","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"5c233abc-7e2f-4646-9fdb-fe005f77ac66","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e2cf3746-8a9b-4067-bbc1-4c8539e345bd","type":"Line"},{"attributes":{"overlay":{"id":"fb571389-6f68-45c5-abc5-3d46df6f60e4","type":"B ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[45]</strong>&gt;</code></p>

# %% [markdown]
# ### Quintic

# %%
X = np.c_[x**5, x**4, x**3, x**2, x, np.ones(len(x))]
res = sm.OLS(y, X).fit()

p = figure(title='Blue = True; Red = OLS')
p.circle(x, y, size=8,color='blue')

xx = np.linspace(-1.25,1.25,100)
p.line(xx, res.predict(np.vander(xx,6)), color='red')
show(p)
# Out:
#     <div class="plotdiv" id="745fd70d-dfc5-4cd7-8c09-fe9fd2325e57"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("745fd70d-dfc5-4cd7-8c09-fe9fd2325e57");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '745fd70d-dfc5-4cd7-8c09-fe9fd2325e57' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"01b68d3d-9f4b-498e-bc41-c3fe9f26517e":{"roots":{"references":[{"attributes":{"callback":null},"id":"9291560d-1427-4fd4-86a4-52a0445dcd52","type":"DataRange1d"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"data_source":{"id":"f8b3b2b4-8229-4e91-8764-57c9d3e591fd","type":"ColumnDataSource"},"glyph":{"id":"a67cd198-ce3c-4bb4-8bd7-434249357514","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"12b2859d-b985-42b9-a167-4019a4b36063","type":"Line"},"selection_glyph":null},"id":"6318bb61-2dde-4c56-8a50-44430d57d345","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"dd2480d6-9a0e-403e-9a2f-943334080aec","type":"WheelZoomTool"},{"attributes":{},"id":"1098c190-352a-4953-8c16-772331828eb3","type":"ToolEvents"},{"attributes":{"callback":null},"id":"9bac38d6-07fb-40ba-bec1-079a241a091b","type":"DataRange1d"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"5727253d-7ff3-47de-83d6-004d1006cf19","type":"BasicTicker"}},"id":"c1576536-a14b-47e0-9738-95e7e55c4a7c","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.99768,-0.69574,-0.40373,-0.10236,0.22024,0.47742,0.82229,1.20044],"y":[2.0885,1.1646,0.3287,0.46013,0.44808,0.10013,-0.32952,-0.32811]}},"id":"5f36558a-780c-457b-8aef-db721e1de8fe","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"a20e7094-219b-49c0-a9b3-2b6460569f76","type":"DataRange1d"},{"attributes":{"plot":{"id":"472e612c-5f6a-4f00-b81e-047db6d716a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"9deb8d4a-3ccd-4366-a7de-77b23a60ebe4","type":"BasicTicker"}},"id":"f8833145-6bef-462e-8716-8a263f35cc4e","type":"Grid"},{"attributes":{"formatter":{"id":"45f78c21-448e-4a83-9243-3f7a7f8fab91","type":"BasicTickFormatter"},"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"},"ticker":{"id":"99cb5ce0-eb47-41fd-b40a-46c3dc4a918e","type":"BasicTicker"}},"id":"99ffd02f-30a3-49e1-a6a3-5ef36f7cb60f","type":"LinearAxis"},{"attributes":{"below":[{"id":"3d13b7a4-3566-410a-b998-ac704297b8c9","type":"LinearAxis"}],"left":[{"id":"b887b697-a016-4ccd-960e-444d42e98ace","type":"LinearAxis"}],"renderers":[{"id":"3d13b7a4-3566-410a-b998-ac704297b8c9","type":"LinearAxis"},{"id":"b17803c6-c525-4ffc-94f6-0738f2453333","type":"Grid"},{"id":"b887b697-a016-4ccd-960e-444d42e98ace","type":"LinearAxis"},{"id":"407a156a-3e87-495a-91d3-9cdf0a2645dc","type":"Grid"},{"id":"b300f322-af5d-466a-83e7-13b918c74777","type":"BoxAnnotation"},{"id":"4c5b1f78-c13e-46e5-9129-ccc4c5444c02","type":"GlyphRenderer"},{"id":"da820297-ccf1-4f24-9a2c-f2b6b7cad68d","type":"GlyphRenderer"}],"title":"Blue = True; Red = OLS","tool_events":{"id":"7a1ec907-7ff3-4203-b6d1-7a1f21edd1d8","type":"ToolEvents"},"tools":[{"id":"f8f1bac8-9a4d-450c-a2b1-043fc7258a40","type":"PanTool"},{"id":"9286850e-b065-41e6-99c5-3768613eb91c","type":"WheelZoomTool"},{"id":"557487de-065a-4582-995f-c47eeb34de4e"," ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[46]</strong>&gt;</code></p>

# %% [markdown]
# ## Regularization

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
ridge = Ridge(alpha = .2)
ridge.fit(np.vander(x, 6), y)

lasso = Lasso(alpha = 1)
lasso.fit(np.vander(x, 6), y)

p = figure(title='Blue = True; Red = OLS')
p.circle(x, y, size=8,color='blue')

xx = np.linspace(-1.25,1.25,100)
p.line(xx, res.predict(np.vander(xx,6)), color='red')
p.line(xx, ridge.predict(np.vander(xx,6)), color='green')
p.line(xx, lasso.predict(np.vander(xx,6)), color='cyan')
show(p)
# Out:
#     <div class="plotdiv" id="a4b294f2-a8a9-4af7-866e-53d84f74e7b3"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a4b294f2-a8a9-4af7-866e-53d84f74e7b3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a4b294f2-a8a9-4af7-866e-53d84f74e7b3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"378d7776-e8bb-4c32-af7b-e0b9eb109e17":{"roots":{"references":[{"attributes":{"callback":null},"id":"9291560d-1427-4fd4-86a4-52a0445dcd52","type":"DataRange1d"},{"attributes":{"plot":{"id":"b5a51987-5e68-4e40-ae01-177425867d38","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9f962c-7be6-499b-b6cd-ce197a3d6b05","type":"BasicTicker"}},"id":"aa1bd6fe-a6b8-4e02-85ff-b64c319e275b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d300354-6a4d-44af-821c-4992da63a528","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1389c5d0-7d03-45c6-a1fa-91bd2078bfa5","type":"Line"},{"attributes":{"data_source":{"id":"f8b3b2b4-8229-4e91-8764-57c9d3e591fd","type":"ColumnDataSource"},"glyph":{"id":"a67cd198-ce3c-4bb4-8bd7-434249357514","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"12b2859d-b985-42b9-a167-4019a4b36063","type":"Line"},"selection_glyph":null},"id":"6318bb61-2dde-4c56-8a50-44430d57d345","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8428e3a9-bb2a-434d-b761-ca7317c6a2c5","subtype":"Figure","type":"Plot"}},"id":"dd2480d6-9a0e-403e-9a2f-943334080aec","type":"WheelZoomTool"},{"attributes":{},"id":"1098c190-352a-4953-8c16-772331828eb3","type":"ToolEvents"},{"attributes":{"callback":null},"id":"9bac38d6-07fb-40ba-bec1-079a241a091b","type":"DataRange1d"},{"attributes":{"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"}},"id":"b490ac3f-7ad0-46e2-b2d3-ded1f296fa51","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"6cee4580-63e4-4eb3-a8fb-782521ee9f19","subtype":"Figure","type":"Plot"},"ticker":{"id":"5727253d-7ff3-47de-83d6-004d1006cf19","type":"BasicTicker"}},"id":"c1576536-a14b-47e0-9738-95e7e55c4a7c","type":"Grid"},{"attributes":{"data_source":{"id":"ce2ef43d-7712-4a3f-83b9-3c11d4888b22","type":"ColumnDataSource"},"glyph":{"id":"ce31394b-8424-42a5-83aa-55e9b8ff559d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"7a6f1a83-1077-4f17-80c0-66ca47b5a582","type":"Line"},"selection_glyph":null},"id":"5222f97a-7f34-4ea7-a2ac-f093d188f5d1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.99768,-0.69574,-0.40373,-0.10236,0.22024,0.47742,0.82229,1.20044],"y":[2.0885,1.1646,0.3287,0.46013,0.44808,0.10013,-0.32952,-0.32811]}},"id":"5f36558a-780c-457b-8aef-db721e1de8fe","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"a20e7094-219b-49c0-a9b3-2b6460569f76","type":"DataRange1d"},{"attributes":{"plot":{"id":"472e612c-5f6a-4f00-b81e-047db6d716a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"9deb8d4a-3ccd-4366-a7de-77b23a60ebe4","type":"BasicTicker"}},"id":"f8833145-6bef-462e-8716-8a263f35cc4e","type":"Grid"},{"attributes":{"formatter":{"id":"45f78c21-448e-4a83-9243-3f7a7f8fab91","type":"BasicTickFormatter"},"plot":{"id":"7b3cd330-9a46-4a4f-ad0e-377bdc7919fa","subtype":"Figure","type":"Plot"},"ticker":{"id":"99cb5ce0-eb47-41fd-b40a-46c3dc4a918e","type":"BasicTicker"}},"id":"99ffd02f-30a3-49e1-a6a3-5ef36f7cb60f","type":"LinearAxis"},{"attributes":{"below":[{"id":"3d13b7a4-3566-410a-b998-ac704297b8c9","type":"LinearAxis"}],"left":[{"id":"b887b697-a016-4ccd-960e-444d42e98ace","type":"LinearAxis"}],"renderers":[{"id":"3d13b7a4-3566-410a-b998-ac704297b8c9","type":"LinearAxis"},{"id":"b17803c6-c525-4ffc-94f6-0738f2453333","type":"Grid"},{"id":"b887b697-a016-4ccd-960e-444d42e98ace","type":"LinearAxis"},{"id":"407a156a-3e87-495a-91d3-9cdf0a2645dc","type":"Grid"},{"id":"b300f322-af5d-466a-83e7-13b918c74777","type":"BoxAnnotation"},{"id":"4c5b1f78-c13e-46e5-9129-ccc4c5444c02","type":"GlyphRenderer"},{"id":"da ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[48]</strong>&gt;</code></p>
